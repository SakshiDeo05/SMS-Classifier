# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
ds = pd.read_csv("spam.csv", encoding='latin1')
ds.head
# Out:
# <bound method NDFrame.head of         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]>

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
ds = ds.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'])

# %%
ds.columns
# Out:
# Index(['v1', 'v2'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
ds['v1'] = le.fit_transform(ds['v1'])

# %%
ds.v1.value_counts()
# Out:
# v1
# 0    4825
# 1     747
# Name: count, dtype: int64

# %%
#checking duplicates
ds.duplicated().sum()
# Out:
# 403

# %%
ds =ds.drop_duplicates()

# %%
ds.shape
# Out:
# (5169, 2)

# %%
ham = ds[ds['v1']==0].sample(653)

# %%
ham.head()
# Out:
#       v1                                                 v2
# 1924   0                                                 Ok
# 1970   0                                     Nvm it's ok...
# 3251   0  Come to medical college at 7pm ......forward i...
# 4180   0          Ok da, i already planned. I wil pick you.
# 744    0    Men like shorter ladies. Gaze up into his eyes.

# %%
spam = ds[ds['v1']==1]

# %%
spam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 653 entries, 2 to 5567
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      653 non-null    int32
#  1   v2      653 non-null    object
# dtypes: int32(1), object(1)
# memory usage: 12.8+ KB

# %%
ds2 = pd.concat([ham,spam],axis=0)

# %%
ds2.head()
# Out:
#       v1                                                 v2
# 1924   0                                                 Ok
# 1970   0                                     Nvm it's ok...
# 3251   0  Come to medical college at 7pm ......forward i...
# 4180   0          Ok da, i already planned. I wil pick you.
# 744    0    Men like shorter ladies. Gaze up into his eyes.

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1306 entries, 1924 to 5567
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      1306 non-null   int32
#  1   v2      1306 non-null   object
# dtypes: int32(1), object(1)
# memory usage: 25.5+ KB

# %%
ds2.duplicated().sum(), ds2.isnull().sum()
# Out:
# (0,
#  v1    0
#  v2    0
#  dtype: int64)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\sakshi d\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\sakshi d\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\sakshi d\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sakshi d\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sakshi d\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sakshi d\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
hamt = ds2[ds2['v1']==1]
spamt = ds2[ds2['v1']==0]

# %%
hamt.head()
# Out:
#     v1                                                 v2
# 2    1  Free entry in 2 a wkly comp to win FA Cup fina...
# 5    1  FreeMsg Hey there darling it's been 3 week's n...
# 8    1  WINNER!! As a valued network customer you have...
# 9    1  Had your mobile 11 months or more? U R entitle...
# 11   1  SIX chances to win CASH! From 100 to 20,000 po...

# %%
ham_txt = " ".join(hamt['v2'])
len(ham_txt)
# Out:
# 90695

# %%
wc = WordCloud(width=900,height=800).generate(ham_txt)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
spamt.head()
# Out:
#       v1                                                 v2
# 1924   0                                                 Ok
# 1970   0                                     Nvm it's ok...
# 3251   0  Come to medical college at 7pm ......forward i...
# 4180   0          Ok da, i already planned. I wil pick you.
# 744    0    Men like shorter ladies. Gaze up into his eyes.

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(ds2['v2'],ds2['v1'],test_size=0.2,random_state=42,stratify=ds2['v1'])

# %%
xtrain.shape,ytrain.shape,xtest.shape,ytest.shape
# Out:
# ((1044,), (1044,), (262,), (262,))

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\sakshi d\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sakshi d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\sakshi d\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 435.7 kB/s eta 0:00:30
#      --------------------------------------- 0.1/12.8 MB 737.3 kB/s eta 0:00:18
#       --------------------------------------- 0.2/12.8 MB 1.2 MB/s eta 0:00:11
#      --- ------------------------------------ 1.0/12.8 MB 4.7 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.5/12.8 MB 5.9 MB/s eta 0:00:02
#      ------ --------------------------------- 2.2/12.8 MB 7.0 MB/s eta 0:00:02
#      ------- -------------------------------- 2.5/12.8 MB 7.6 MB/s eta 0:00:02
#      --------- ------------------------------ 3.2/12.8 MB 7.7 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.6/12.8 MB 8.1 MB/s eta 0:00:02
#      ------------- -------------------------- 4.4/12.8 MB 9.0 MB/s eta 0:00:01
#      --------------- ------------------------ 4.9/12.8 MB 9.4 MB/s eta 0:00:01
#      --------------- ------------------------ 4.9/12.8 MB 9.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.6/12.8 MB 8.9 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 8.9 MB/s eta 0:00:01
#      --------------------- ------------------ 6.9/12.8 MB 9.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.4/12.8 MB 9.4 MB/s eta 0:00:01
#      ------------------------ --------------- 7.9/12.8 MB 9.7 MB/s eta 0:00:01
#      ------------------------- -------------- 8.3/12.8 MB 9.8 MB/s eta 0:00:01
#      -------------------------- ------------- 8.5/12.8 MB 9.3 MB/s eta 0:00:01
#      --------------------------- ------------ 8.8/12.8 MB 9.4 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.1/12.8 MB 9.1 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.6/12.8 MB 9.1 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 9.0 MB/s eta 0:00:01
#      -------------------------------- ------ 10.5/12.8 MB 10.6 MB/s eta 0:00:01
#      --------------------------------- ----- 10.8/12.8 MB 10.2 MB/s eta 0:00:01
#      ---------------------------------- ---- 11.4/12.8 MB 10.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 9.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 9.6 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\sakshi d\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sakshi d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sakshi d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\sakshi d\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\sakshi d\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sakshi d\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import sklearn.pipeline

# %%
nlp = spacy.load("en_core_web_sm")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
model = make_pipeline(TfidfVectorizer(), MultinomialNB())
model.fit(xtrain, ytrain)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
ypred = model.predict(xtest)
ypred[:5]
# Out:
# array([0, 1, 1, 1, 0])

# %%
from sklearn.metrics import classification_report as cr
print(cr(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       131
#            1       0.98      0.98      0.98       131
#
#     accuracy                           0.98       262
#    macro avg       0.98      0.98      0.98       262
# weighted avg       0.98      0.98      0.98       262

# %%
#testing 
sample_txt = 'hurray !! you won a 25 million dollors'

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy

# Load spaCy model (make sure you have spaCy installed)
nlp = spacy.load("en_core_web_sm")

# Assuming xtrain and ytrain are your training data
model = Pipeline([
    ('text preprocessing', TfidfVectorizer(
        tokenizer=lambda txt: [token.lemma_ for token in nlp(txt)],
        stop_words='english',
        ngram_range=(1, 2),
        max_features=500,
        token_pattern=None  # Set token_pattern to None
    )),
    ('text classifier', RandomForestClassifier())
])

# Fit the model on the training data
model.fit(xtrain, ytrain)
# Out:
# C:\Users\Sakshi D\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['I', 'far', 'make', 'whereaft'] not in stop_words.
#   warnings.warn(
# Pipeline(steps=[('text preprocessing',
#                  TfidfVectorizer(max_features=500, ngram_range=(1, 2),
#                                  stop_words='english', token_pattern=None,
#                                  tokenizer=<function <lambda> at 0x000001AB8FCF7F60>)),
#                 ('text classifier', RandomForestClassifier())])

# %%
ypred = model.predict([sample_txt])

# %%
print(ypred[0])
# Out:
# 1
